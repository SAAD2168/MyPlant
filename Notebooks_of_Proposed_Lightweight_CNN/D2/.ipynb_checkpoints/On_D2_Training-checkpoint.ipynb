# %% [markdown]
# # Import Libraries

# %%
import numpy             as np
import keras.backend     as K
import matplotlib.pyplot as plt

from sklearn.preprocessing                import LabelEncoder
from sklearn.metrics                      import classification_report, accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.initializers        import glorot_uniform
from tensorflow.keras.models              import Model
from tensorflow.keras.layers              import Input,ZeroPadding2D, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from tensorflow.keras.layers              import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from tensorflow.keras.layers              import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models              import Model, load_model
from tensorflow.keras                     import layers
from IPython.display                      import SVG
from tensorflow.keras.utils               import model_to_dot
from time                                 import time
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.utils               import plot_model

# %%
from tensorflow.keras.preprocessing.image import img_to_array
import os

from tensorflow.keras.callbacks import Callback

import pandas as pd

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dense, Dropout, GlobalAveragePooling2D, SeparableConv2D

# %% [markdown]
# # Resume of variables

# %%
# Save Directory
save_folder = r'C:\Users\LAPECI\Documents'

num_classes_dataset=21

# Model Name
model_name = 'HS_128D2_Test5'

# train Directory
train_dir = r'C:\Users\LAPECI\Downloads\Plant\train'
valid_dir = r'C:\Users\LAPECI\Downloads\Plant\valid'




# Name saved files after training
savefig_F1Score=f"{model_name}_F1Score_Over_Epochs"
savefig_Precision=f"{model_name}_Precision_Over_Epochs"
savefig_Recall=f"{model_name}_Recall_Over_Epochs"
save_csv_metrics_f1score_precision_recall=f"{model_name}_metrics_history_f1_precision_recall.csv"

H5model_name=f"{model_name}_H5_Model.h5"

savefig_accuracy=f"{model_name}_Accuracy_Over_Epochs"
savefig_loss=f"{model_name}_Loss_Over_Epochs"



save_csv_accuracy_history=f"{model_name}_accuracy_history.csv"
save_csv_loss_history=f"{model_name}_loss_history.csv"
savefig_c_matrix_onH5=f"{model_name}_confusion_matrix"

save_csv_report_onH5=f"{model_name}_classification_report_128x128_OnH5.txt"

save_csv_yval_ypredict_onH5=f"{model_name}_Y_val_Y_predict.csv"


# Define the save path and filename
tflite_filename = f"{model_name}_TFLite.tflite"

savefig_c_matrix_OnTFlite=f"{model_name}_confusion_matrix_On_TFLite"
save_csv_report_OnTFLite=f"{model_name}_classification_report_128x128_OnTFlite.txt"
save_csv_yval_ypredict_OnTFLite=f"{model_name}_Y_val_Y_predict_TFLite.csv"

# %% [markdown]
# # SE Block Definition

# %%
def se_block(input_tensor, ratio=8):
    channel_axis = -1
    filters = input_tensor.shape[channel_axis]

    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(filters // ratio, activation='relu')(se)
    se = Dense(filters, activation='sigmoid')(se)
    se = Reshape((1, 1, filters))(se)

    return Multiply()([input_tensor, se])

# %% [markdown]
# # HardSwish Definition

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer

class HardSwish(Layer):
    def call(self, x):
        return x * tf.nn.relu6(x + 3) / 6

# %%
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, PReLU,
    Input, Multiply, Reshape
)

# %% [markdown]
# # Proposed Lightweight CNN : ProposedLightweightCNNHS128 - D2

# %%
input_shape = (128, 128, 3)

def ProposedLightweightCNNHS128D1(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # Input
    x = Conv2D(16, (3, 3), strides=(2, 2), padding='same')(inputs) 
    x = HardSwish()(x)
    x = BatchNormalization()(x)
    
    # Bloc 1 
    x = SeparableConv2D(32, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = HardSwish()(x)
    
    x = Conv2D(32, (1, 1))(x) 
    x = se_block(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) 
    
    # Bloc 2 
    x = SeparableConv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = HardSwish()(x)
    x = Conv2D(64, (1, 1))(x) 
    x = se_block(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) 
    
    
    x = SeparableConv2D(128, (3, 3), padding='same')(x)
    x = HardSwish()(x)
    x = MaxPooling2D(pool_size=(2, 2))(x) 

    # Classification
    x = GlobalAveragePooling2D()(x)
    x = Dense(64)(x) 
    x = HardSwish()(x)
    x = Dropout(0.3)(x)
    output = Dense(num_classes, activation='softmax')(x)
    
    return Model(inputs=inputs, outputs=output)

model = ProposedLightweightCNNHS128D1(input_shape, num_classes_dataset)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 64, 64, 16)   448         ['input_1[0][0]']
#
#  hard_swish (HardSwish)         (None, 64, 64, 16)   0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 16)  64          ['hard_swish[0][0]']
#  alization)
#
#  separable_conv2d (SeparableCon  (None, 64, 64, 32)  688         ['batch_normalization[0][0]']
#  v2D)
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 32)  128         ['separable_conv2d[0][0]']
#  rmalization)
#
#  hard_swish_1 (HardSwish)       (None, 64, 64, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   1056        ['hard_swish_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['conv2d_1[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            132         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 32)           160         ['dense[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 32)     0           ['dense_1[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 32)   0           ['conv2d_1[0][0]',
#                                                                   'reshape[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['multiply[0][0]']
#
#  separable_conv2d_1 (SeparableC  (None, 32, 32, 64)  2400        ['max_pooling2d[0][0]']
#  onv2D)
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['separable_conv2d_1[0][0]']
#  rmalization)
#
#  hard_swish_2 (HardSwish)       (None, 32, 32, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   4160        ['hard_swish_2[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 64)          0           ['conv2d_2[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 8)            520         ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 64)           576         ['dense_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 64)     0           ['dense_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 32, 32, 64)   0           ['conv2d_2[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['multiply_1[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 16, 16, 128)  8896       ['max_pooling2d_1[0][0]']
#  onv2D)
#
#  hard_swish_3 (HardSwish)       (None, 16, 16, 128)  0           ['separable_conv2d_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)   0           ['hard_swish_3[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 128)         0           ['max_pooling2d_2[0][0]']
#  obalAveragePooling2D)
#
#  dense_4 (Dense)                (None, 64)           8256        ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  hard_swish_4 (HardSwish)       (None, 64)           0           ['dense_4[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['hard_swish_4[0][0]']
#
#  dense_5 (Dense)                (None, 21)           1365        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 29,105
# Trainable params: 28,881
# Non-trainable params: 224
# __________________________________________________________________________________________________

# %%
img_height, img_width = 128, 128 
batch_size = 32



train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    label_mode='categorical'
)


val_ds = tf.keras.utils.image_dataset_from_directory(
    valid_dir,
    image_size=(128, 128),
    batch_size=32,
    label_mode='categorical'
)


def normalize(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.map(normalize).cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.map(normalize).cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 10236 files belonging to 21 classes.
# Found 2550 files belonging to 21 classes.

# %%
class MetricsCallback(Callback):
    def __init__(self, validation_dataset):
        super(MetricsCallback, self).__init__()
        self.validation_dataset = validation_dataset
        self.f1_scores = []
        self.precisions = []
        self.recalls = []

        
        print("[INFO] Extraction des labels de validation pour le Callback...")
        y_true = []
        for _, labels in validation_dataset:
            y_true.extend(np.argmax(labels.numpy(), axis=1))
        self.y_true_classes = np.array(y_true)

    def on_epoch_end(self, epoch, logs=None):
        y_pred = self.model.predict(self.validation_dataset, verbose=0)
        y_pred_classes = np.argmax(y_pred, axis=1)

        
        precision = precision_score(self.y_true_classes, y_pred_classes, average='weighted', zero_division=0)
        recall = recall_score(self.y_true_classes, y_pred_classes, average='weighted', zero_division=0)
        f1 = f1_score(self.y_true_classes, y_pred_classes, average='weighted', zero_division=0)

        
        self.precisions.append(precision)
        self.recalls.append(recall)
        self.f1_scores.append(f1)

        
        print(f" — val_precision: {precision:.4f} — val_recall: {recall:.4f} — val_f1: {f1:.4f}")

# %%
metrics_callback = MetricsCallback(val_ds)
# Out:
# [INFO] Extraction des labels de validation pour le Callback...

# %% [markdown]
# # Start Training the model

# %%
import time
from datetime import datetime


start_time = datetime.now()
print("Début de l'entraînement à :", start_time.strftime("%H:%M:%S"))



history = model.fit(train_ds, validation_data=val_ds, epochs=100, verbose=1,callbacks=[metrics_callback])



end_time = datetime.now()
print("Fin de l'entraînement à :", end_time.strftime("%H:%M:%S"))


duration = end_time - start_time
print("Durée de l'entraînement :", str(duration))
# Out:
# Début de l'entraînement à : 06:17:05
# Epoch 1/100
# 318/320 [============================>.] - ETA: 0s - loss: 2.8939 - accuracy: 0.1038 — val_precision: 0.0200 — val_recall: 0.0573 — val_f1: 0.0244
# 320/320 [==============================] - 16s 21ms/step - loss: 2.8920 - accuracy: 0.1038 - val_loss: 3.0129 - val_accuracy: 0.0573
# Epoch 2/100
# 318/320 [============================>.] - ETA: 0s - loss: 2.2525 - accuracy: 0.2516 — val_precision: 0.2592 — val_recall: 0.2659 — val_f1: 0.2184
# 320/320 [==============================] - 6s 20ms/step - loss: 2.2508 - accuracy: 0.2518 - val_loss: 2.2213 - val_accuracy: 0.2659
# Epoch 3/100
# 320/320 [==============================] - ETA: 0s - loss: 1.8335 - accuracy: 0.3904 — val_precision: 0.5229 — val_recall: 0.5404 — val_f1: 0.4847
# 320/320 [==============================] - 6s 20ms/step - loss: 1.8335 - accuracy: 0.3904 - val_loss: 1.4437 - val_accuracy: 0.5404
# Epoch 4/100
# 319/320 [============================>.] - ETA: 0s - loss: 1.4541 - accuracy: 0.5017 — val_precision: 0.6433 — val_recall: 0.6125 — val_f1: 0.5873
# 320/320 [==============================] - 6s 20ms/step - loss: 1.4531 - accuracy: 0.5021 - val_loss: 1.1921 - val_accuracy: 0.6125
# Epoch 5/100
# 319/320 [============================>.] - ETA: 0s - loss: 1.2221 - accuracy: 0.5809 — val_precision: 0.7279 — val_recall: 0.7286 — val_f1: 0.7138
# 320/320 [==============================] - 6s 20ms/step - loss: 1.2214 - accuracy: 0.5811 - val_loss: 0.9011 - val_accuracy: 0.7286
# Epoch 6/100
# 318/320 [============================>.] - ETA: 0s - loss: 1.0453 - accuracy: 0.6422 — val_precision: 0.7841 — val_recall: 0.7710 — val_f1: 0.7642
# 320/320 [==============================] - 6s 20ms/step - loss: 1.0449 - accuracy: 0.6419 - val_loss: 0.8193 - val_accuracy: 0.7710
# Epoch 7/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.9052 - accuracy: 0.6858 — val_precision: 0.8143 — val_recall: 0.8067 — val_f1: 0.8059
# 320/320 [==============================] - 6s 20ms/step - loss: 0.9062 - accuracy: 0.6853 - val_loss: 0.6652 - val_accuracy: 0.8067
# Epoch 8/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.7902 - accuracy: 0.7339 — val_precision: 0.8235 — val_recall: 0.8169 — val_f1: 0.8137
# 320/320 [==============================] - 6s 20ms/step - loss: 0.7894 - accuracy: 0.7343 - val_loss: 0.5677 - val_accuracy: 0.8169
# Epoch 9/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.6975 - accuracy: 0.7646 — val_precision: 0.8580 — val_recall: 0.8525 — val_f1: 0.8508
# 320/320 [==============================] - 6s 20ms/step - loss: 0.6970 - accuracy: 0.7648 - val_loss: 0.4962 - val_accuracy: 0.8525
# Epoch 10/100
# 320/320 [==============================] - ETA: 0s - loss: 0.6305 - accuracy: 0.7889 — val_precision: 0.8791 — val_recall: 0.8773 — val_f1: 0.8763
# 320/320 [==============================] - 6s 20ms/step - loss: 0.6305 - accuracy: 0.7889 - val_loss: 0.4088 - val_accuracy: 0.8773
# Epoch 11/100
# 320/320 [==============================] - ETA: 0s - loss: 0.5653 - accuracy: 0.8057 — val_precision: 0.8886 — val_recall: 0.8839 — val_f1: 0.8829
# 320/320 [==============================] - 6s 20ms/step - loss: 0.5653 - accuracy: 0.8057 - val_loss: 0.3911 - val_accuracy: 0.8839
# Epoch 12/100
# 317/320 [============================>.] - ETA: 0s - loss: 0.5247 - accuracy: 0.8205 — val_precision: 0.9048 — val_recall: 0.9016 — val_f1: 0.9012
# 320/320 [==============================] - 6s 20ms/step - loss: 0.5242 - accuracy: 0.8209 - val_loss: 0.3314 - val_accuracy: 0.9016
# Epoch 13/100
# 317/320 [============================>.] - ETA: 0s - loss: 0.4810 - accuracy: 0.8385 — val_precision: 0.9165 — val_recall: 0.9118 — val_f1: 0.9115
# 320/320 [==============================] - 6s 20ms/step - loss: 0.4814 - accuracy: 0.8386 - val_loss: 0.3088 - val_accuracy: 0.9118
# Epoch 14/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.4403 - accuracy: 0.8503 — val_precision: 0.9194 — val_recall: 0.9161 — val_f1: 0.9159
# 320/320 [==============================] - 6s 20ms/step - loss: 0.4398 - accuracy: 0.8505 - val_loss: 0.2792 - val_accuracy: 0.9161
# Epoch 15/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.4112 - accuracy: 0.8622 — val_precision: 0.9191 — val_recall: 0.9149 — val_f1: 0.9144
# 320/320 [==============================] - 6s 20ms/step - loss: 0.4112 - accuracy: 0.8622 - val_loss: 0.2640 - val_accuracy: 0.9149
# Epoch 16/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.3875 - accuracy: 0.8690 — val_precision: 0.9374 — val_recall: 0.9341 — val_f1: 0.9340
# 320/320 [==============================] - 6s 20ms/step - loss: 0.3872 - accuracy: 0.8691 - val_loss: 0.2384 - val_accuracy: 0.9341
# Epoch 17/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.3561 - accuracy: 0.8780 — val_precision: 0.9285 — val_recall: 0.9255 — val_f1: 0.9253
# 320/320 [==============================] - 6s 20ms/step - loss: 0.3558 - accuracy: 0.8779 - val_loss: 0.2294 - val_accuracy: 0.9255
# Epoch 18/100
# 320/320 [==============================] - ETA: 0s - loss: 0.3402 - accuracy: 0.8841 — val_precision: 0.9383 — val_recall: 0.9341 — val_f1: 0.9340
# 320/320 [==============================] - 6s 20ms/step - loss: 0.3402 - accuracy: 0.8841 - val_loss: 0.2172 - val_accuracy: 0.9341
# Epoch 19/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.3178 - accuracy: 0.8931 — val_precision: 0.9452 — val_recall: 0.9427 — val_f1: 0.9426
# 320/320 [==============================] - 6s 20ms/step - loss: 0.3172 - accuracy: 0.8933 - val_loss: 0.1973 - val_accuracy: 0.9427
# Epoch 20/100
# 320/320 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.8960 — val_precision: 0.9506 — val_recall: 0.9471 — val_f1: 0.9469
# 320/320 [==============================] - 6s 20ms/step - loss: 0.3023 - accuracy: 0.8960 - val_loss: 0.1828 - val_accuracy: 0.9471
# Epoch 21/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.2871 - accuracy: 0.9029 — val_precision: 0.9504 — val_recall: 0.9490 — val_f1: 0.9491
# 320/320 [==============================] - 6s 20ms/step - loss: 0.2866 - accuracy: 0.9031 - val_loss: 0.1731 - val_accuracy: 0.9490
# Epoch 22/100
# 320/320 [==============================] - ETA: 0s - loss: 0.2694 - accuracy: 0.9084 — val_precision: 0.9509 — val_recall: 0.9467 — val_f1: 0.9465
# 320/320 [==============================] - 6s 20ms/step - loss: 0.2694 - accuracy: 0.9084 - val_loss: 0.1750 - val_accuracy: 0.9467
# Epoch 23/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.2581 - accuracy: 0.9131 — val_precision: 0.9497 — val_recall: 0.9475 — val_f1: 0.9474
# 320/320 [==============================] - 6s 20ms/step - loss: 0.2584 - accuracy: 0.9129 - val_loss: 0.1581 - val_accuracy: 0.9475
# Epoch 24/100
# 320/320 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9198 — val_precision: 0.9522 — val_recall: 0.9506 — val_f1: 0.9504
# 320/320 [==============================] - 6s 20ms/step - loss: 0.2430 - accuracy: 0.9198 - val_loss: 0.1537 - val_accuracy: 0.9506
# Epoch 25/100
# 320/320 [==============================] - ETA: 0s - loss: 0.2377 - accuracy: 0.9208 — val_precision: 0.9548 — val_recall: 0.9537 — val_f1: 0.9538
# 320/320 [==============================] - 6s 20ms/step - loss: 0.2377 - accuracy: 0.9208 - val_loss: 0.1401 - val_accuracy: 0.9537
# Epoch 26/100
# 320/320 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9255 — val_precision: 0.9576 — val_recall: 0.9549 — val_f1: 0.9547
# 320/320 [==============================] - 6s 20ms/step - loss: 0.2247 - accuracy: 0.9255 - val_loss: 0.1435 - val_accuracy: 0.9549
# Epoch 27/100
# 320/320 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9298 — val_precision: 0.9567 — val_recall: 0.9557 — val_f1: 0.9557
# 320/320 [==============================] - 6s 20ms/step - loss: 0.2150 - accuracy: 0.9298 - val_loss: 0.1270 - val_accuracy: 0.9557
# Epoch 28/100
# 320/320 [==============================] - ETA: 0s - loss: 0.2100 - accuracy: 0.9296 — val_precision: 0.9555 — val_recall: 0.9541 — val_f1: 0.9541
# 320/320 [==============================] - 6s 20ms/step - loss: 0.2100 - accuracy: 0.9296 - val_loss: 0.1294 - val_accuracy: 0.9541
# Epoch 29/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.1943 - accuracy: 0.9379 — val_precision: 0.9635 — val_recall: 0.9604 — val_f1: 0.9603
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1942 - accuracy: 0.9379 - val_loss: 0.1189 - val_accuracy: 0.9604
# Epoch 30/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.1911 - accuracy: 0.9356 — val_precision: 0.9577 — val_recall: 0.9561 — val_f1: 0.9562
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1907 - accuracy: 0.9358 - val_loss: 0.1210 - val_accuracy: 0.9561
# Epoch 31/100
# 320/320 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9404 — val_precision: 0.9662 — val_recall: 0.9639 — val_f1: 0.9637
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1879 - accuracy: 0.9404 - val_loss: 0.1085 - val_accuracy: 0.9639
# Epoch 32/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.1849 - accuracy: 0.9373 — val_precision: 0.9571 — val_recall: 0.9557 — val_f1: 0.9558
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1849 - accuracy: 0.9373 - val_loss: 0.1177 - val_accuracy: 0.9557
# Epoch 33/100
# 320/320 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9411 — val_precision: 0.9661 — val_recall: 0.9639 — val_f1: 0.9638
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1705 - accuracy: 0.9411 - val_loss: 0.0976 - val_accuracy: 0.9639
# Epoch 34/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.1708 - accuracy: 0.9452 — val_precision: 0.9667 — val_recall: 0.9639 — val_f1: 0.9638
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1703 - accuracy: 0.9454 - val_loss: 0.1032 - val_accuracy: 0.9639
# Epoch 35/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.1620 - accuracy: 0.9465 — val_precision: 0.9695 — val_recall: 0.9675 — val_f1: 0.9673
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1617 - accuracy: 0.9466 - val_loss: 0.0950 - val_accuracy: 0.9675
# Epoch 36/100
# 320/320 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9487 — val_precision: 0.9707 — val_recall: 0.9686 — val_f1: 0.9684
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1556 - accuracy: 0.9487 - val_loss: 0.0968 - val_accuracy: 0.9686
# Epoch 37/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.1527 - accuracy: 0.9479 — val_precision: 0.9482 — val_recall: 0.9412 — val_f1: 0.9414
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1525 - accuracy: 0.9481 - val_loss: 0.1587 - val_accuracy: 0.9412
# Epoch 38/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.1476 - accuracy: 0.9500 — val_precision: 0.9696 — val_recall: 0.9675 — val_f1: 0.9672
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1484 - accuracy: 0.9497 - val_loss: 0.0917 - val_accuracy: 0.9675
# Epoch 39/100
# 320/320 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9507 — val_precision: 0.9674 — val_recall: 0.9651 — val_f1: 0.9651
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1422 - accuracy: 0.9507 - val_loss: 0.0916 - val_accuracy: 0.9651
# Epoch 40/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.1364 - accuracy: 0.9538 — val_precision: 0.9766 — val_recall: 0.9749 — val_f1: 0.9746
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1364 - accuracy: 0.9538 - val_loss: 0.0817 - val_accuracy: 0.9749
# Epoch 41/100
# 320/320 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9557 — val_precision: 0.9734 — val_recall: 0.9714 — val_f1: 0.9712
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1315 - accuracy: 0.9557 - val_loss: 0.0821 - val_accuracy: 0.9714
# Epoch 42/100
# 320/320 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9562 — val_precision: 0.9651 — val_recall: 0.9631 — val_f1: 0.9631
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1304 - accuracy: 0.9562 - val_loss: 0.0929 - val_accuracy: 0.9631
# Epoch 43/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.1251 - accuracy: 0.9578 — val_precision: 0.9720 — val_recall: 0.9698 — val_f1: 0.9696
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1254 - accuracy: 0.9576 - val_loss: 0.0854 - val_accuracy: 0.9698
# Epoch 44/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.1192 - accuracy: 0.9597 — val_precision: 0.9513 — val_recall: 0.9451 — val_f1: 0.9449
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1197 - accuracy: 0.9597 - val_loss: 0.1470 - val_accuracy: 0.9451
# Epoch 45/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.1230 - accuracy: 0.9583 — val_precision: 0.9714 — val_recall: 0.9690 — val_f1: 0.9688
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1231 - accuracy: 0.9583 - val_loss: 0.0823 - val_accuracy: 0.9690
# Epoch 46/100
# 317/320 [============================>.] - ETA: 0s - loss: 0.1172 - accuracy: 0.9594 — val_precision: 0.9768 — val_recall: 0.9761 — val_f1: 0.9759
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1173 - accuracy: 0.9594 - val_loss: 0.0698 - val_accuracy: 0.9761
# Epoch 47/100
# 320/320 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 0.9623 — val_precision: 0.9660 — val_recall: 0.9647 — val_f1: 0.9647
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1136 - accuracy: 0.9623 - val_loss: 0.0858 - val_accuracy: 0.9647
# Epoch 48/100
# 320/320 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9594 — val_precision: 0.9762 — val_recall: 0.9745 — val_f1: 0.9742
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1145 - accuracy: 0.9594 - val_loss: 0.0694 - val_accuracy: 0.9745
# Epoch 49/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.1042 - accuracy: 0.9639 — val_precision: 0.9750 — val_recall: 0.9745 — val_f1: 0.9745
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1041 - accuracy: 0.9640 - val_loss: 0.0662 - val_accuracy: 0.9745
# Epoch 50/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0990 - accuracy: 0.9652 — val_precision: 0.9785 — val_recall: 0.9773 — val_f1: 0.9771
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0990 - accuracy: 0.9651 - val_loss: 0.0626 - val_accuracy: 0.9773
# Epoch 51/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9629 — val_precision: 0.9736 — val_recall: 0.9718 — val_f1: 0.9714
# 320/320 [==============================] - 6s 20ms/step - loss: 0.1022 - accuracy: 0.9631 - val_loss: 0.0821 - val_accuracy: 0.9718
# Epoch 52/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0996 - accuracy: 0.9656 — val_precision: 0.9813 — val_recall: 0.9796 — val_f1: 0.9794
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0996 - accuracy: 0.9656 - val_loss: 0.0595 - val_accuracy: 0.9796
# Epoch 53/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9656 — val_precision: 0.9769 — val_recall: 0.9765 — val_f1: 0.9763
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0967 - accuracy: 0.9656 - val_loss: 0.0593 - val_accuracy: 0.9765
# Epoch 54/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0953 - accuracy: 0.9665 — val_precision: 0.9784 — val_recall: 0.9776 — val_f1: 0.9775
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0955 - accuracy: 0.9663 - val_loss: 0.0571 - val_accuracy: 0.9776
# Epoch 55/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9665 — val_precision: 0.9787 — val_recall: 0.9769 — val_f1: 0.9767
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0955 - accuracy: 0.9665 - val_loss: 0.0621 - val_accuracy: 0.9769
# Epoch 56/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0929 - accuracy: 0.9682 — val_precision: 0.9796 — val_recall: 0.9788 — val_f1: 0.9786
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0930 - accuracy: 0.9682 - val_loss: 0.0544 - val_accuracy: 0.9788
# Epoch 57/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9682 — val_precision: 0.9805 — val_recall: 0.9788 — val_f1: 0.9786
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0910 - accuracy: 0.9682 - val_loss: 0.0594 - val_accuracy: 0.9788
# Epoch 58/100
# 317/320 [============================>.] - ETA: 0s - loss: 0.0864 - accuracy: 0.9695 — val_precision: 0.9706 — val_recall: 0.9690 — val_f1: 0.9691
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0866 - accuracy: 0.9696 - val_loss: 0.0721 - val_accuracy: 0.9690
# Epoch 59/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9691 — val_precision: 0.9756 — val_recall: 0.9745 — val_f1: 0.9743
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0879 - accuracy: 0.9691 - val_loss: 0.0639 - val_accuracy: 0.9745
# Epoch 60/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9695 — val_precision: 0.9749 — val_recall: 0.9741 — val_f1: 0.9739
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0852 - accuracy: 0.9695 - val_loss: 0.0576 - val_accuracy: 0.9741
# Epoch 61/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9730 — val_precision: 0.9768 — val_recall: 0.9765 — val_f1: 0.9764
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0824 - accuracy: 0.9727 - val_loss: 0.0538 - val_accuracy: 0.9765
# Epoch 62/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0811 - accuracy: 0.9715 — val_precision: 0.9795 — val_recall: 0.9780 — val_f1: 0.9778
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0809 - accuracy: 0.9717 - val_loss: 0.0554 - val_accuracy: 0.9780
# Epoch 63/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9701 — val_precision: 0.9765 — val_recall: 0.9761 — val_f1: 0.9760
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0819 - accuracy: 0.9701 - val_loss: 0.0566 - val_accuracy: 0.9761
# Epoch 64/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9719 — val_precision: 0.9795 — val_recall: 0.9776 — val_f1: 0.9774
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0764 - accuracy: 0.9719 - val_loss: 0.0611 - val_accuracy: 0.9776
# Epoch 65/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.9749 — val_precision: 0.9791 — val_recall: 0.9788 — val_f1: 0.9787
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0738 - accuracy: 0.9749 - val_loss: 0.0529 - val_accuracy: 0.9788
# Epoch 66/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0772 - accuracy: 0.9718 — val_precision: 0.9778 — val_recall: 0.9769 — val_f1: 0.9767
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0770 - accuracy: 0.9719 - val_loss: 0.0556 - val_accuracy: 0.9769
# Epoch 67/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0749 - accuracy: 0.9728 — val_precision: 0.9795 — val_recall: 0.9788 — val_f1: 0.9787
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0747 - accuracy: 0.9728 - val_loss: 0.0480 - val_accuracy: 0.9788
# Epoch 68/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0743 - accuracy: 0.9724 — val_precision: 0.9728 — val_recall: 0.9722 — val_f1: 0.9723
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0747 - accuracy: 0.9722 - val_loss: 0.0614 - val_accuracy: 0.9722
# Epoch 69/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0710 - accuracy: 0.9751 — val_precision: 0.9798 — val_recall: 0.9780 — val_f1: 0.9778
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0709 - accuracy: 0.9752 - val_loss: 0.0529 - val_accuracy: 0.9780
# Epoch 70/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0678 - accuracy: 0.9743 — val_precision: 0.9817 — val_recall: 0.9808 — val_f1: 0.9806
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0679 - accuracy: 0.9744 - val_loss: 0.0452 - val_accuracy: 0.9808
# Epoch 71/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9740 — val_precision: 0.9817 — val_recall: 0.9804 — val_f1: 0.9802
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0677 - accuracy: 0.9740 - val_loss: 0.0514 - val_accuracy: 0.9804
# Epoch 72/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9775 — val_precision: 0.9793 — val_recall: 0.9788 — val_f1: 0.9787
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0661 - accuracy: 0.9776 - val_loss: 0.0484 - val_accuracy: 0.9788
# Epoch 73/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9760 — val_precision: 0.9720 — val_recall: 0.9710 — val_f1: 0.9708
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0663 - accuracy: 0.9760 - val_loss: 0.0692 - val_accuracy: 0.9710
# Epoch 74/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9766 — val_precision: 0.9805 — val_recall: 0.9792 — val_f1: 0.9790
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0664 - accuracy: 0.9765 - val_loss: 0.0500 - val_accuracy: 0.9792
# Epoch 75/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0630 - accuracy: 0.9769 — val_precision: 0.9829 — val_recall: 0.9820 — val_f1: 0.9818
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0633 - accuracy: 0.9767 - val_loss: 0.0448 - val_accuracy: 0.9820
# Epoch 76/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9781 — val_precision: 0.9765 — val_recall: 0.9761 — val_f1: 0.9760
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0604 - accuracy: 0.9780 - val_loss: 0.0578 - val_accuracy: 0.9761
# Epoch 77/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9755 — val_precision: 0.9742 — val_recall: 0.9722 — val_f1: 0.9719
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0630 - accuracy: 0.9756 - val_loss: 0.0649 - val_accuracy: 0.9722
# Epoch 78/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0574 - accuracy: 0.9797 — val_precision: 0.9827 — val_recall: 0.9812 — val_f1: 0.9810
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0575 - accuracy: 0.9796 - val_loss: 0.0445 - val_accuracy: 0.9812
# Epoch 79/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0626 - accuracy: 0.9774 — val_precision: 0.9765 — val_recall: 0.9757 — val_f1: 0.9755
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0625 - accuracy: 0.9774 - val_loss: 0.0557 - val_accuracy: 0.9757
# Epoch 80/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0621 - accuracy: 0.9764 — val_precision: 0.9730 — val_recall: 0.9722 — val_f1: 0.9720
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0619 - accuracy: 0.9765 - val_loss: 0.0615 - val_accuracy: 0.9722
# Epoch 81/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0554 - accuracy: 0.9811 — val_precision: 0.9829 — val_recall: 0.9816 — val_f1: 0.9814
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0557 - accuracy: 0.9809 - val_loss: 0.0401 - val_accuracy: 0.9816
# Epoch 82/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9774 — val_precision: 0.9780 — val_recall: 0.9776 — val_f1: 0.9776
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0586 - accuracy: 0.9774 - val_loss: 0.0497 - val_accuracy: 0.9776
# Epoch 83/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9789 — val_precision: 0.9806 — val_recall: 0.9800 — val_f1: 0.9799
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0554 - accuracy: 0.9789 - val_loss: 0.0451 - val_accuracy: 0.9800
# Epoch 84/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9793 — val_precision: 0.9798 — val_recall: 0.9788 — val_f1: 0.9786
# 320/320 [==============================] - 7s 21ms/step - loss: 0.0564 - accuracy: 0.9793 - val_loss: 0.0466 - val_accuracy: 0.9788
# Epoch 85/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9803 — val_precision: 0.9797 — val_recall: 0.9792 — val_f1: 0.9791
# 320/320 [==============================] - 7s 20ms/step - loss: 0.0515 - accuracy: 0.9805 - val_loss: 0.0425 - val_accuracy: 0.9792
# Epoch 86/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0569 - accuracy: 0.9791 — val_precision: 0.9789 — val_recall: 0.9788 — val_f1: 0.9787
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0568 - accuracy: 0.9792 - val_loss: 0.0421 - val_accuracy: 0.9788
# Epoch 87/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9819 — val_precision: 0.9720 — val_recall: 0.9702 — val_f1: 0.9700
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0510 - accuracy: 0.9819 - val_loss: 0.0743 - val_accuracy: 0.9702
# Epoch 88/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9801 — val_precision: 0.9756 — val_recall: 0.9753 — val_f1: 0.9752
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0542 - accuracy: 0.9801 - val_loss: 0.0491 - val_accuracy: 0.9753
# Epoch 89/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9809 — val_precision: 0.9823 — val_recall: 0.9816 — val_f1: 0.9814
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0506 - accuracy: 0.9809 - val_loss: 0.0436 - val_accuracy: 0.9816
# Epoch 90/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0477 - accuracy: 0.9819 — val_precision: 0.9810 — val_recall: 0.9796 — val_f1: 0.9794
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0478 - accuracy: 0.9818 - val_loss: 0.0504 - val_accuracy: 0.9796
# Epoch 91/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9795 — val_precision: 0.9766 — val_recall: 0.9757 — val_f1: 0.9758
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0502 - accuracy: 0.9795 - val_loss: 0.0511 - val_accuracy: 0.9757
# Epoch 92/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9802 — val_precision: 0.9821 — val_recall: 0.9812 — val_f1: 0.9810
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0510 - accuracy: 0.9802 - val_loss: 0.0390 - val_accuracy: 0.9812
# Epoch 93/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9815 — val_precision: 0.9799 — val_recall: 0.9788 — val_f1: 0.9786
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0479 - accuracy: 0.9815 - val_loss: 0.0453 - val_accuracy: 0.9788
# Epoch 94/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9813 — val_precision: 0.9775 — val_recall: 0.9769 — val_f1: 0.9767
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0505 - accuracy: 0.9814 - val_loss: 0.0499 - val_accuracy: 0.9769
# Epoch 95/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9802 — val_precision: 0.9752 — val_recall: 0.9745 — val_f1: 0.9743
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0491 - accuracy: 0.9802 - val_loss: 0.0541 - val_accuracy: 0.9745
# Epoch 96/100
# 319/320 [============================>.] - ETA: 0s - loss: 0.0459 - accuracy: 0.9824 — val_precision: 0.9834 — val_recall: 0.9820 — val_f1: 0.9817
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0458 - accuracy: 0.9824 - val_loss: 0.0437 - val_accuracy: 0.9820
# Epoch 97/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0491 - accuracy: 0.9815 — val_precision: 0.9798 — val_recall: 0.9792 — val_f1: 0.9791
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0492 - accuracy: 0.9815 - val_loss: 0.0424 - val_accuracy: 0.9792
# Epoch 98/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0450 - accuracy: 0.9818 — val_precision: 0.9808 — val_recall: 0.9796 — val_f1: 0.9794
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0454 - accuracy: 0.9816 - val_loss: 0.0425 - val_accuracy: 0.9796
# Epoch 99/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9805 — val_precision: 0.9776 — val_recall: 0.9761 — val_f1: 0.9758
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0509 - accuracy: 0.9806 - val_loss: 0.0514 - val_accuracy: 0.9761
# Epoch 100/100
# 318/320 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9809 — val_precision: 0.9804 — val_recall: 0.9800 — val_f1: 0.9799
# 320/320 [==============================] - 6s 20ms/step - loss: 0.0479 - accuracy: 0.9809 - val_loss: 0.0446 - val_accuracy: 0.9800
# Fin de l'entraînement à : 06:27:58
# Durée de l'entraînement : 0:10:53.782967

# %% [markdown]
# # Plot Metrics

# %%
f1_scores = metrics_callback.f1_scores
precisions = metrics_callback.precisions
recalls = metrics_callback.recalls


plt.plot(f1_scores, color='#F3126F', linewidth=2, marker='s', markersize=4, markerfacecolor='white',
         markeredgecolor='#F3126F',
         markeredgewidth=1.5, label='F1-score')

plt.xlabel('Epochs', fontsize=10, weight='bold')
plt.ylabel('F1 Score', fontsize=10, weight='bold')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()

plt.savefig(savefig_F1Score, dpi=300, bbox_inches='tight')
plt.show()


plt.plot(precisions, color='#126FF3', linewidth=2, marker='s', markersize=4, markerfacecolor='white',
         markeredgecolor='#126FF3',
         markeredgewidth=1.5,label='Precision')
plt.xlabel('Epochs', fontsize=10, weight='bold')
plt.ylabel('Precision', fontsize=10, weight='bold')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()

plt.savefig(savefig_Precision, dpi=300, bbox_inches='tight')
plt.show()

plt.plot(recalls,color='#F39C12', linewidth=2, marker='s', markersize=4, markerfacecolor='white',
         markeredgecolor='#F39C12',
         markeredgewidth=1.5, label='Recall')
plt.xlabel('Epochs', fontsize=10, weight='bold')
plt.ylabel('Recall', fontsize=10, weight='bold')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(savefig_Recall, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Save Metrics

# %%
metrics_df = pd.DataFrame({
    'epoch': range(1, len(f1_scores) + 1),  
    'f1_score': f1_scores,                  
    'precision': precisions,                
    'recall': recalls                       
})

metrics_df.to_csv(save_csv_metrics_f1score_precision_recall, index=False)

# %% [markdown]
# # Save Model H5

# %%
model.save(H5model_name)

# %% [markdown]
# # Model Validation

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import tensorflow as tf


model = tf.keras.models.load_model(H5model_name,custom_objects={'HardSwish': HardSwish})


print("[INFO] Extraction des labels réels...")
Y_val = []
for _, labels in val_ds:
    Y_val.extend(np.argmax(labels.numpy(), axis=1))
Y_val = np.array(Y_val)

print("[INFO] Calcul des prédictions sur val_ds...")
y_predict = model.predict(val_ds)
Y_predict = np.argmax(y_predict, axis=1)


accuracy  = accuracy_score(Y_val, Y_predict)
precision = precision_score(Y_val, Y_predict, average='weighted')
recall    = recall_score(Y_val, Y_predict, average='weighted')
f1        = f1_score(Y_val, Y_predict, average='weighted')

print("-" * 30)
print(f"Accuracy:  {accuracy:.15f}")
print(f"Precision: {precision:.15f}")
print(f"Recall:    {recall:.15f}")
print(f"F1 Score:  {f1:.15f}")
# Out:
# [INFO] Extraction des labels réels...
# [INFO] Calcul des prédictions sur val_ds...
# 80/80 [==============================] - 1s 6ms/step
# ------------------------------
# Accuracy:  0.980000000000000
# Precision: 0.980384498032347
# Recall:    0.980000000000000
# F1 Score:  0.979909868690236

# %% [markdown]
# # Plot Accuracy over Epochs

# %%
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(history.history["accuracy"], 
         color='#2E86C1',
         linewidth=2, 
         marker='o',
         markersize=4,
         markerfacecolor='white',
         markeredgecolor='#2E86C1',
         markeredgewidth=1.5,
         label="Training Accuracy")
plt.plot(history.history["val_accuracy"], 
         color='#E74C3C',
         linewidth=2, 
         marker='s',
         markersize=4,
         markerfacecolor='white',
         markeredgecolor='#E74C3C',
         markeredgewidth=1.5,
         label="Validation Accuracy")

plt.xlabel("Epoch", fontsize=10, weight='bold')
plt.ylabel("Accuracy", fontsize=10, weight='bold')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=9)
plt.ylim(0, 1.1)

plt.tight_layout()

plt.savefig(savefig_accuracy, dpi=300, bbox_inches='tight')
plt.show()

# Create figure with subplots
plt.figure(figsize=(15, 10))
# Plot loss curves
plt.subplot(2, 2, 1)
plt.plot(history.history["loss"], 
         color='#2ECC71',
         linewidth=2, 
         marker='o',
         markersize=4,
         markerfacecolor='white',
         markeredgecolor='#2ECC71',
         markeredgewidth=1.5,
         label="Training Loss")
plt.plot(history.history["val_loss"], 
         color='#F39C12',
         linewidth=2, 
         marker='s',
         markersize=4,
         markerfacecolor='white',
         markeredgecolor='#F39C12',
         markeredgewidth=1.5,
         label="Validation Loss")

plt.xlabel("Epoch", fontsize=10, weight='bold')
plt.ylabel("Loss", fontsize=10, weight='bold')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=9)

plt.tight_layout()

plt.savefig(savefig_loss, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Save Accuracy

# %%
accuracy_data = pd.DataFrame({
    'epoch': range(1, len(history.history['accuracy']) + 1),  
    'training_accuracy': history.history['accuracy'],         
    'validation_accuracy': history.history['val_accuracy']    
})

accuracy_data.to_csv(save_csv_accuracy_history, index=False)

# %% [markdown]
# # Save Loss

# %%
loss_data = pd.DataFrame({
    'epoch': range(1, len(history.history['loss']) + 1),  
    'training_loss': history.history['loss'],         
    'validation_loss': history.history['val_loss']    
})

loss_data.to_csv(save_csv_loss_history, index=False)

# %% [markdown]
# # Plot Confusion Matrix on H5

# %%
import os
New_Plant_Disease_DatasetClasses = sorted(os.listdir(train_dir))

# %%
cm = confusion_matrix(Y_val, Y_predict)
print("Confusion Matrix")

plt.figure(figsize=(15, 12))

sns.heatmap(cm,
            annot=True,
            fmt='d',
            xticklabels=New_Plant_Disease_DatasetClasses,
            yticklabels=New_Plant_Disease_DatasetClasses,
            cmap='Blues',
            square=True,
            annot_kws={'size': 6, 'weight': 'bold', 'color': 'black'}, 
            cbar_kws={'label': 'Count'},
            linewidths=1.0,  
            linecolor='white',
            vmin=0, 
            vmax=np.max(cm))  

plt.ylabel('Actual', fontsize=12, weight='bold')
plt.xlabel('Predicted', fontsize=12, weight='bold')
plt.title('Confusion Matrix', fontsize=14, pad=20, weight='bold')

plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(rotation=0, fontsize=8)

plt.gcf().axes[-1].tick_params(labelsize=10)  
plt.gcf().axes[-1].set_ylabel('Count', fontsize=10, weight='bold')

plt.tight_layout(pad=1.5)

plt.savefig(savefig_c_matrix_onH5, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Confusion Matrix

# %% [markdown]
# # Save and show classification report on H5

# %%
print("\n[INFO] Rapport de Classification détaillé :")
report = classification_report(Y_val, 
                               Y_predict, 
                               target_names=New_Plant_Disease_DatasetClasses, 
                               digits=4)

print(report)

with open(save_csv_report_onH5, "w") as f:
    f.write(report)
# Out:
# [INFO] Rapport de Classification détaillé :
#                                precision    recall  f1-score   support
#
#   Bitter_Gourd__Downey_Mildew     0.9913    1.0000    0.9956       114
#      Bitter_Gourd__Fresh_Leaf     0.9909    0.9909    0.9909       110
#   Bitter_Gourd__Fusarium_Wilt     0.8876    0.7900    0.8360       100
#    Bitter_Gourd__Mosaic_Virus     0.8397    0.9167    0.8765       120
#     Bottle_gourd__Anthracnose     1.0000    1.0000    1.0000       120
#   Bottle_gourd__Downey_Mildew     1.0000    1.0000    1.0000       136
#      Bottle_gourd__Fresh_Leaf     0.9903    0.9903    0.9903       103
#        Cauliflower__Black_Rot     1.0000    1.0000    1.0000       112
#    Cauliflower__Downey_Mildew     1.0000    0.9902    0.9951       102
#       Cauliflower__Fresh_Leaf     0.9813    1.0000    0.9906       105
# Cucumber__Anthracnose_Lesions     1.0000    1.0000    1.0000       107
#       Cucumber__Downey_Mildew     0.9739    1.0000    0.9868       112
#          Cucumber__Fresh_Leaf     1.0000    0.9714    0.9855       105
#         Eggplant__Begomovirus     1.0000    0.9653    0.9823       144
# Eggplant__Cercopora_Leaf_Spot     1.0000    1.0000    1.0000       144
#          Eggplant__Fresh_Leaf     1.0000    1.0000    1.0000       154
#   Eggplant__Verticillium_Wilt     0.9669    1.0000    0.9832       146
#        Tomato__Bacterial_Spot     0.9590    1.0000    0.9791       117
#            Tomato__Fresh_Leaf     0.9912    0.9576    0.9741       118
#       Tomato__Leaf_Curl_Virus     0.9933    0.9868    0.9900       151
#          Tomato__Spotted_Wilt     1.0000    0.9846    0.9922       130
#
#                      accuracy                         0.9800      2550
#                     macro avg     0.9793    0.9783    0.9785      2550
#                  weighted avg     0.9804    0.9800    0.9799      2550

# %% [markdown]
# # Save Y_Val et Y_Predict on H5

# %%
results_df = pd.DataFrame({
    'Y_val': Y_val,          
    'Y_predict': Y_predict   
})

results_df.to_csv(save_csv_yval_ypredict_onH5, index=False)

# %% [markdown]
# # Conversion Tensorflowlite

# %%
model = tf.keras.models.load_model(H5model_name,custom_objects={'HardSwish': HardSwish})

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

full_save_path = os.path.join(save_folder, tflite_filename)

with open(full_save_path, 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\LAPECI\AppData\Local\Temp\tmpaxfythga\assets
# INFO:tensorflow:Assets written to: C:\Users\LAPECI\AppData\Local\Temp\tmpaxfythga\assets

# %% [markdown]
# # Validation Tensorflowlite

# %%
interpreter = tf.lite.Interpreter(os.path.join(save_folder,tflite_filename))

# %%
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

tflite_predictions = []
all_y_true = []
inference_times = []

print("[INFO] Lancement de l'inférence TFLite sur le dataset de validation...")

for images, labels in val_ds:
    # On stocke les vrais labels
    all_y_true.extend(np.argmax(labels.numpy(), axis=1))
    
    # Pour chaque image dans le batch
    for i in range(images.shape[0]):
        single_img = np.expand_dims(images[i], axis=0) # Ajoute la dimension batch (1, 128, 128, 3)
        
        start = time.time()
        # Configurer le tenseur d'entrée
        interpreter.set_tensor(input_details[0]['index'], single_img)
        # Lancer l'inférence
        interpreter.invoke()
        # Récupérer le résultat
        output_data = interpreter.get_tensor(output_details[0]['index'])
        end = time.time()
        
        inference_times.append(end - start)
        tflite_predictions.append(np.argmax(output_data))

# 4. Conversion en tableaux NumPy
Y_val_tflite = np.array(all_y_true)
Y_pred_tflite = np.array(tflite_predictions)

# 5. Calcul des métriques
accuracy  = accuracy_score(Y_val_tflite, Y_pred_tflite)
precision = precision_score(Y_val_tflite, Y_pred_tflite, average='weighted')
recall    = recall_score(Y_val_tflite, Y_pred_tflite, average='weighted')
f1        = f1_score(Y_val_tflite, Y_pred_tflite, average='weighted')
avg_time  = np.mean(inference_times)

print("-" * 30)
print(f"Résultats TFLite (128x128):")
print(f"Accuracy:  {accuracy:.15f}")
print(f"Precision: {precision:.15f}")
print(f"Recall:    {recall:.15f}")
print(f"F1 Score:  {f1:.15f}")
print(f"Temps d'inférence moyen: {avg_time:.4f} s ({1/avg_time:.2f} FPS)")
# Out:
# [INFO] Lancement de l'inférence TFLite sur le dataset de validation...
# ------------------------------
# Résultats TFLite (128x128):
# Accuracy:  0.980000000000000
# Precision: 0.980384498032347
# Recall:    0.980000000000000
# F1 Score:  0.979909868690236
# Temps d'inférence moyen: 0.0033 s (306.89 FPS)

# %% [markdown]
# # Plot Confusion Matrix on Tensorflowlite

# %%
cm = confusion_matrix(Y_val_tflite, Y_pred_tflite)
print("Confusion Matrix On TFLite")

plt.figure(figsize=(15, 12))

sns.heatmap(cm,
            annot=True,
            fmt='d',
            xticklabels=New_Plant_Disease_DatasetClasses,
            yticklabels=New_Plant_Disease_DatasetClasses,
            cmap='Blues',
            square=True,
            annot_kws={'size': 6, 'weight': 'bold', 'color': 'black'},  
            cbar_kws={'label': 'Count'},
            linewidths=1.0,  
            linecolor='white',
            vmin=0,  
            vmax=np.max(cm))  

plt.ylabel('Actual', fontsize=12, weight='bold')
plt.xlabel('Predicted', fontsize=12, weight='bold')
plt.title('Confusion Matrix On TFLite', fontsize=14, pad=20, weight='bold')

plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(rotation=0, fontsize=8)

plt.gcf().axes[-1].tick_params(labelsize=10)  
plt.gcf().axes[-1].set_ylabel('Count', fontsize=10, weight='bold') 

plt.tight_layout(pad=1.5)

plt.savefig(savefig_c_matrix_OnTFlite, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Confusion Matrix On TFLite

# %% [markdown]
# # Save and Show Classification report on TensorflowLite

# %%
print("\n[INFO] Rapport de Classification détaillé :")
report = classification_report(Y_val_tflite, 
                               Y_pred_tflite, 
                               target_names=New_Plant_Disease_DatasetClasses, 
                               digits=4)

print(report)

with open(save_csv_report_OnTFLite, "w") as f:
    f.write(report)
# Out:
# [INFO] Rapport de Classification détaillé :
#                                precision    recall  f1-score   support
#
#   Bitter_Gourd__Downey_Mildew     0.9913    1.0000    0.9956       114
#      Bitter_Gourd__Fresh_Leaf     0.9909    0.9909    0.9909       110
#   Bitter_Gourd__Fusarium_Wilt     0.8876    0.7900    0.8360       100
#    Bitter_Gourd__Mosaic_Virus     0.8397    0.9167    0.8765       120
#     Bottle_gourd__Anthracnose     1.0000    1.0000    1.0000       120
#   Bottle_gourd__Downey_Mildew     1.0000    1.0000    1.0000       136
#      Bottle_gourd__Fresh_Leaf     0.9903    0.9903    0.9903       103
#        Cauliflower__Black_Rot     1.0000    1.0000    1.0000       112
#    Cauliflower__Downey_Mildew     1.0000    0.9902    0.9951       102
#       Cauliflower__Fresh_Leaf     0.9813    1.0000    0.9906       105
# Cucumber__Anthracnose_Lesions     1.0000    1.0000    1.0000       107
#       Cucumber__Downey_Mildew     0.9739    1.0000    0.9868       112
#          Cucumber__Fresh_Leaf     1.0000    0.9714    0.9855       105
#         Eggplant__Begomovirus     1.0000    0.9653    0.9823       144
# Eggplant__Cercopora_Leaf_Spot     1.0000    1.0000    1.0000       144
#          Eggplant__Fresh_Leaf     1.0000    1.0000    1.0000       154
#   Eggplant__Verticillium_Wilt     0.9669    1.0000    0.9832       146
#        Tomato__Bacterial_Spot     0.9590    1.0000    0.9791       117
#            Tomato__Fresh_Leaf     0.9912    0.9576    0.9741       118
#       Tomato__Leaf_Curl_Virus     0.9933    0.9868    0.9900       151
#          Tomato__Spotted_Wilt     1.0000    0.9846    0.9922       130
#
#                      accuracy                         0.9800      2550
#                     macro avg     0.9793    0.9783    0.9785      2550
#                  weighted avg     0.9804    0.9800    0.9799      2550

# %% [markdown]
# # Save Y_val_tflite et Y_pred_tflite  on TensorflowLite

# %%
results_df = pd.DataFrame({
    'Y_val': Y_val_tflite,         
    'Y_predict': Y_pred_tflite   
})

results_df.to_csv(save_csv_yval_ypredict_OnTFLite, index=False)

# %% [markdown]
# # FLOPs

# %%
import tensorflow as tf
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

model_path = H5model_name
model = tf.keras.models.load_model(model_path,custom_objects={'HardSwish': HardSwish})

full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1] + list(model.input_shape[1:]), model.inputs[0].dtype)
)

frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

if flops is not None:
    print(f"\n" + "="*30)
    print(f"MODÈLE : {model_path}")
    print(f"FLOPs totaux : {flops.total_float_ops:,}")
    print(f"GigaFLOPs    : {flops.total_float_ops / 1e9:.4f} GFLOPs")
    print("="*30)
# Out:
# WARNING:tensorflow:From C:\Users\LAPECI\anaconda3\envs\amine\lib\site-packages\tensorflow\python\ops\nn_ops.py:5250: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# WARNING:tensorflow:From C:\Users\LAPECI\anaconda3\envs\amine\lib\site-packages\tensorflow\python\ops\nn_ops.py:5250: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# ==============================
# MODÈLE : HS_128D2_Test5_H5_Model.h5
# FLOPs totaux : 36,697,642
# GigaFLOPs    : 0.0367 GFLOPs
# ==============================
